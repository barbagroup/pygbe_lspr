# %%
import numpy

# %%
w_d0, Cext_d0, C_an, err = numpy.loadtxt('data/lambda_Cext_Cext_an_error_silver_7.5.txt',
                                        unpack = True)

w_d1 , Cext_d1 = numpy.loadtxt('data/wave_cext_d/multiple_sphere_d=1.txt', 
                               unpack = True)
w_d2 , Cext_d2 = numpy.loadtxt('data/wave_cext_d/multiple_sphere_d=2.txt', 
                               unpack = True)
w_d4 , Cext_d4 = numpy.loadtxt('data/wave_cext_d/multiple_sphere_d=4.txt', 
                               unpack = True)

# %%
numpy.where(w_d0==380)
# Out:
# (array([30]),)

# %%
numpy.where(w_d0==390)
# Out:
# (array([40]),)

# %%
numpy.where(Cext_d0==max(Cext_d0))
# Out:
# (array([34]),)

# %%
w_d0 = w_d0[30:41]
Cext_d0 = Cext_d0[30:41]

# %%
from matplotlib import pyplot, rcParams
# %matplotlib inline

# %%
pyplot.figure(figsize=(9,6))

pyplot.plot(w_d0, Cext_d0, ls='-', c='k', lw=2, label='infty')
pyplot.plot(w_d1, Cext_d1, ls='-', c='b', lw=2, label='d1')
pyplot.plot(w_d2, Cext_d2, ls='-', c='r', lw=2, label='d2')
pyplot.plot(w_d4, Cext_d4, ls='-', c='g', lw=2, label='d4')

pyplot.grid(ls=':')
pyplot.legend(loc='best');

# %%
numpy.linspace(380,390,21)
# Out:
# array([ 380. ,  380.5,  381. ,  381.5,  382. ,  382.5,  383. ,  383.5,
#         384. ,  384.5,  385. ,  385.5,  386. ,  386.5,  387. ,  387.5,
#         388. ,  388.5,  389. ,  389.5,  390. ])
