# %%
import numpy

# %%
w , Cext = numpy.loadtxt('data/wave_cext_d/wave_cext_d_infty.txt', 
                               unpack = True)
w_d1 , Cext_d1 = numpy.loadtxt('data/wave_cext_d/multiple_sphere_d=1.txt', 
                               unpack = True)

# %%
w_c , Cext_c = numpy.loadtxt('data/wave_cext_d/chris/wave_cext_d_infty_chris.txt', 
                               unpack = True)
w_d1_c , Cext_d1_c = numpy.loadtxt('data/wave_cext_d/chris/multiple_sphere_d=1chris.txt', 
                               unpack = True)

# %%
max(Cext)
# Out:
# 7759.3213208500001

# %%
max(Cext_c)
# Out:
# 7758.2045207600004

# %%
numpy.where(Cext==max(Cext))
# Out:
# (array([7]),)

# %%
numpy.where(Cext_c==max(Cext_c))
# Out:
# (array([7]),)

# %%
from matplotlib import pyplot, rcParams
# %matplotlib inline

# %%
pyplot.figure(figsize=(9,6))

pyplot.plot(w, Cext, ls='-', c='k', lw=2, label='infty')
pyplot.plot(w_d1, Cext_d1, ls='-', c='b', lw=2, label='d1')
#pyplot.plot(w_d2, Cext_d2, ls='-', c='r', lw=2, label='d2')
#pyplot.plot(w_d4, Cext_d4, ls='-', c='g', lw=2, label='d4')

pyplot.xticks(numpy.linspace(min(w), max(w), 11), rotation=25)
#pyplot.ylim(6000,8000)
pyplot.grid(ls=':')
pyplot.title('Naty - BSA Protein')
pyplot.legend(loc='best');

# %%
pyplot.figure(figsize=(9,6))

pyplot.plot(w_c, Cext_c, ls='-', c='k', lw=2, label='infty')
pyplot.plot(w_d1_c, Cext_d1_c, ls='-', c='b', lw=2, label='d1')
#pyplot.plot(w_d2, Cext_d2, ls='-', c='r', lw=2, label='d2')
#pyplot.plot(w_d4, Cext_d4, ls='-', c='g', lw=2, label='d4')

pyplot.xticks(numpy.linspace(min(w), max(w), 11), rotation=25)
#pyplot.ylim(6000,8000)
pyplot.grid(ls=':')
pyplot.title('Chris - PTG14 Protein')
pyplot.legend(loc='best');
